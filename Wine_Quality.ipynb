# %% [markdown]
# ## **Implementing SVC on Red  Quality Dataset**

# %% [markdown]
# Importing python modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.svm import SVC

# %% [markdown]
# Loading the dataset

# %%
dataset=pd.read_csv('wine-quality.csv')
dataset
# Out:
#        type  fixed acidity  volatile acidity  ...  sulphates  alcohol  quality
# 0     white            7.0             0.270  ...       0.45      8.8        6
# 1     white            6.3             0.300  ...       0.49      9.5        6
# 2     white            8.1             0.280  ...       0.44     10.1        6
# 3     white            7.2             0.230  ...       0.40      9.9        6
# 4     white            7.2             0.230  ...       0.40      9.9        6
# ...     ...            ...               ...  ...        ...      ...      ...
# 6492    red            6.2             0.600  ...       0.58     10.5        5
# 6493    red            5.9             0.550  ...       0.76     11.2        6
# 6494    red            6.3             0.510  ...       0.75     11.0        6
# 6495    red            5.9             0.645  ...       0.71     10.2        5
# 6496    red            6.0             0.310  ...       0.66     11.0        6
#
# ...

# %%
dataset['type'].unique()
# Out:
# array(['white', 'red'], dtype=object)

# %%
data=dataset.replace({'type':'white'},0)
data=data.replace({'type':'red'},1)

# %%
data['type'].unique()
# Out:
# array([0, 1])

# %%
colo=('red','blue')
fig,ax=plt.subplots()
for n_class in range(2):
  ax.scatter(x[y==n_class][:,0],x[y==n_class][:,1],c=colo[n_class],s=len(x),label=str(n_class))

# %% [markdown]
# Splitting Input and Output

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data=data.to_numpy()

# %%
data.shape
# Out:
# (6497, 13)

# %%
x=data[:,1:13]
x.shape
# Out:
# (6497, 12)

# %%
y=data[:,0]
y.shape
# Out:
# (6497,)

# %%
x
# Out:
# array([[ 7.   ,  0.27 ,  0.36 , ...,  0.45 ,  8.8  ,  6.   ],
#        [ 6.3  ,  0.3  ,  0.34 , ...,  0.49 ,  9.5  ,  6.   ],
#        [ 8.1  ,  0.28 ,  0.4  , ...,  0.44 , 10.1  ,  6.   ],
#        ...,
#        [ 6.3  ,  0.51 ,  0.13 , ...,  0.75 , 11.   ,  6.   ],
#        [ 5.9  ,  0.645,  0.12 , ...,  0.71 , 10.2  ,  5.   ],
#        [ 6.   ,  0.31 ,  0.47 , ...,  0.66 , 11.   ,  6.   ]])

# %%
y
# Out:
# array([0., 0., 0., ..., 1., 1., 1.])

# %% [markdown]
# Splitting the data into Training set and Testing Set

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
svc=SVC(kernel='linear')
svc.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_predict=svc.predict(x_test)
y_predict
# Out:
# array([0., 0., 1., ..., 0., 0., 0.])

# %%
print(confusion_matrix(y_test,y_predict))
# Out:
# [[1000    3]
#  [  10  287]]

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      1003
#          1.0       0.99      0.97      0.98       297
#
#     accuracy                           0.99      1300
#    macro avg       0.99      0.98      0.99      1300
# weighted avg       0.99      0.99      0.99      1300

# %% [markdown]
# ## **Implimenting KSVM using SCIKIT-LEARN**

# %%
poly_classification=SVC(kernel='poly',degree=2)
poly_classification.fit(x_train,y_train)
# Out:
# SVC(degree=2, kernel='poly')

# %%
y_predict=svc.predict(x_test)
y_predict
# Out:
# array([0., 0., 1., ..., 0., 0., 0.])

# %%
print(confusion_matrix(y_test,y_predict))
# Out:
# [[1000    3]
#  [  10  287]]

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      1003
#          1.0       0.99      0.97      0.98       297
#
#     accuracy                           0.99      1300
#    macro avg       0.99      0.98      0.99      1300
# weighted avg       0.99      0.99      0.99      1300
